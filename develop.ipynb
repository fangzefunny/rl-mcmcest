# %%
import pickle
import numpy as np 
import matplotlib.pyplot as plt

# %%
with open('data/rlq_scan.pkl', 'rb')as handle:
    samples = pickle.load(handle)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
samples['alpha'].shape
# Out:
# (200000, 3)

# %%
plt.hist(samples['alpha'][:, 0])
# Out:
# (array([4.3480e+03, 2.9905e+04, 5.5815e+04, 5.2645e+04, 3.4453e+04,
#         1.6256e+04, 5.3580e+03, 1.0820e+03, 1.2600e+02, 1.2000e+01]),
#  array([0.04238654, 0.14498039, 0.24757424, 0.35016808, 0.45276195,
#         0.55535579, 0.65794963, 0.76054347, 0.86313736, 0.9657312 ,
#         1.06832504]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(samples['alpha'][:, 1])
# Out:
# (array([8.7473e+04, 5.0600e+04, 2.9019e+04, 1.8258e+04, 1.0001e+04,
#         3.5480e+03, 8.6800e+02, 1.9000e+02, 3.7000e+01, 6.0000e+00]),
#  array([0.01169192, 0.14462119, 0.27755049, 0.41047975, 0.54340905,
#         0.67633832, 0.80926758, 0.94219685, 1.07512617, 1.20805538,
#         1.3409847 ]),
#  <BarContainer object of 10 artists>)

# %%
-.21*.38+.44, -.66*.38+.44, .90*.38+.44
# Out:
# (0.3602, 0.18919999999999998, 0.782)

# %%
-1.71*.77+1.53, -.66*.77+1.53, .47*.77+1.53
# Out:
# (0.21330000000000005, 1.0218, 1.8919000000000001)
