# %%
import pickle
import numpy as np 
import matplotlib.pyplot as plt

# %%
with open('data/rlq.pkl', 'rb')as handle:
    samples = pickle.load(handle)

# %%
plt.hist(samples['alpha'])
# Out:
# (array([6.2690e+03, 2.1940e+04, 2.3509e+04, 1.5692e+04, 7.9010e+03,
#         3.1490e+03, 1.1520e+03, 3.0500e+02, 6.9000e+01, 1.4000e+01]),
#  array([0.05454409, 0.12339124, 0.19223839, 0.26108554, 0.32993269,
#         0.39877984, 0.46762699, 0.53647411, 0.60532129, 0.67416841,
#         0.74301559]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(samples['beta'])
# Out:
# (array([2.7000e+01, 7.7600e+02, 6.2210e+03, 1.9810e+04, 2.6929e+04,
#         1.8138e+04, 6.5760e+03, 1.3450e+03, 1.6100e+02, 1.7000e+01]),
#  array([2.41811204, 2.65662289, 2.89513373, 3.13364458, 3.37215543,
#         3.61066628, 3.84917736, 4.08768797, 4.32619905, 4.56470966,
#         4.80322075]),
#  <BarContainer object of 10 artists>)
