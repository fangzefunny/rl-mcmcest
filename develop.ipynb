# %%
import pickle
import numpy as np 
import matplotlib.pyplot as plt

# %%
with open('data/rlq.pkl', 'rb')as handle:
    samples = pickle.load(handle)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
plt.hist(samples['alpha'])
# Out:
# (array([1.1697e+04, 8.3020e+03, 8.9000e+01, 8.4230e+03, 7.6970e+03,
#         2.8060e+03, 7.5500e+02, 1.8500e+02, 4.2000e+01, 4.0000e+00]),
#  array([-0.36994195, -0.22642976, -0.08291757,  0.06059462,  0.20410681,
#          0.347619  ,  0.49113119,  0.63464338,  0.77815557,  0.92166775,
#          1.06517994]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(samples['beta'])
